# %%
number=[10,20,30]
number[1]=40
print(number)
# Out:
# [10, 40, 30]

# %%
number=[10,20,30,10,20]
empty_list=[]
print(type(empty_list))
empty_list=list()
print(empty_list)
# Out:
# <class 'list'>
# []

# %%
num=[30,60,50]
print(num)

fruit=["apple","banana"]
print(fruit)

mixed_type=[10,12,6,'shruti',True]
print(mixed_type)
# Out:
# [30, 60, 50]
# ['apple', 'banana']
# [10, 12, 6, 'shruti', True]

# %%
nums=[1,2,3,1,2]
print(len(nums))
print(nums[3])
print(nums[1:4])
print(nums[3:4])
# Out:
# 5
# 1
# [2, 3, 1]
# [1]

# %%
fruit=["apple","banana"]
fruit.append("mango")
print(fruit)

fruit.remove("banana")
print(fruit)
# Out:
# ['apple', 'banana', 'mango']
# ['apple', 'mango']

# %%
nums=[1,2,3,1,2]
print(nums.index(1))
# Out:
# 0

# %%
nums=[1,2,3,1,2]
print(nums.count(2))
# Out:
# 2

# %%
num1=[1,2,3]
num2=[4,5,6]
num1.extend(num2)
print(num1)

num1.extend([10,20,30])
print(num1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 10, 20, 30]

# %%
nums=[3,4,5]
nums.insert(2,2)
print(nums)
# Out:
# [3, 4, 2, 5]

# %%
nums=[45,67,23,54]
print(nums.sort())
print(nums)
# Out:
# None
# [23, 45, 54, 67]

# %%
fruit=["apple","cherry","mango","banana"]
print(fruit.sort())
print(fruit)
# Out:
# None
# ['apple', 'banana', 'cherry', 'mango']

# %%
nums=[65,46,38,86]
print(num.sort(reverse=True))
print(nums)
# Out:
# None
# [65, 46, 38, 86]

# %%
nums=[23,45,67,89]
print(nums.reverse())
print(nums)
# Out:
# None
# [89, 67, 45, 23]

# %%
sub1=["digital"]
sub2=["analog"]
sub3=["network"]
sub1.extend(sub2)
print(sub1)
sub1.extend(sub3)
print(sub1)
# Out:
# ['digital', 'analog']
# ['digital', 'analog', 'network']
