# %%
print("welcome")
print
# Out:
# welcome

# %%
a=3
b=5
c=a*b
print(c)
# Out:
# 15

# %%
name ="shruti"
age ="19"
print(f"my Name is {name} and i am {age}year old.")
# Out:
# my Name is shruti and i am 19year old.

# %%
name ="shruti"
age ="19"
print("Name:",name,"Age:",age,sep="|")
# Out:
# Name:|shruti|Age:|19

# %%
print("welcome",end="|")
print("dkte")
# Out:
# welcome|dkte

# %%
print("python\n")
print("program")
# Out:
# python
#
# program

# %%
print("welcome",end="--")
print("dkte")
# Out:
# welcome--dkte

# %%
num=int(input("enter number:"))
print("Number is :",num)
# Out:
# enter number:34
# Number is : 34

# %%
a=int(input("enter num1:"))
b=int(input("enter num2:"))
c=a/b

print("a/b:",c)
# Out:
# enter num1:32
# enter num2:4
# a/b: 8.0
