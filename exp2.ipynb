# %%
a=input("enter num1")
b=input("enter num 2")
c=a+b
print(c)
# Out:
# enter num121
# enter num 231
# 2131

# %%
a=int(input("enter num1"))
b=int(input("enter num 2"))
c=a+b
print(c)
# Out:
# enter num120
# enter num 210
# 30

# %%
str1="dkte"
print(str1)
print(type(str1))

str2='10'
print(str2)
# Out:
# dkte
# <class 'str'>
# 10

# %%
str1='dkte'
str2='college'
print (str1+str2)

str3='shruti\t'
str4='kadam'
print(str3 + str4)

str5='riya\n'
str6='shruti\n'
str7='archana'
print(str5 + str6 + str7)
# Out:
# dktecollege
# shruti	kadam
# riya
# shruti
# archana

# %%
str1='dkte'
print(len(str1))

str2="dkte college"
print(len(str2))

str3='dktecollege'
print(len(str3))
# Out:
# 4
# 12
# 11

# %%
str1='shruti'
print(str1[0])
print(str1[1])
print(str1[2])
print(str1[3])
print(str1[4])
print(str1[5])
# Out:
# s
# h
# r
# u
# t
# i

# %%
str1="dkte"
print(str1[1:3])
print (str1[ :3])
print(str1[2:])
print(str1[ : ])
# Out:
# kt
# dkt
# te
# dkte

# %%
str1='dkte'
print(str1[-3:-1])
print(str1[ : -1])
print(str1[-3: ])
# Out:
# kt
# dkt
# kte

# %%
str1="I am Coder"
print(str1.startswith ("I"))

str2="I am Coder"
print(str1.endswith("r"))

str3="shruti"
print(str3.upper())

str4="riya"
print( str4.lower())

str5="shrutika bargale"
print(str5.title())

str6="archana"
print(str6.isalpha())

str7="SQUAD"
print(str7.isupper())

str8="forever"
print(str8.islower())

str9= '123'
print(str9.isnumeric())

str10="3567898"
print(str10.isdigit())

str11="23"
print(str11.isdecimal())

city='Ichalkaranji'
print(city.find("i"))

city='Ichalkaranji'
print(city.count("a"))

city='ichalkaranji'
print(city.replace("i","s"))
# Out:
# True
# True
# SHRUTI
# riya
# Shrutika Bargale
# True
# True
# True
# True
# True
# True
# 11
# 3
# schalkaranjs
